# %% [markdown]
# # Configuração do Boto3 no Amazon Bedrock
# ---
#
# Neste caderno de demonstração, demonstramos como usar o [`boto3` Python SDK] (https://boto3.amazonaws.com/v1/documentation/api/latest/index.html) para trabalhar com os modelos de base do [Amazon Bedrock] (https://aws.amazon.com/bedrock/).
#
# ---
# ## Pré-requisitos
#
# Execute as células nesta seção para instalar os pacotes exigidos pelos cadernos. ⚠️ Você verá erros de dependência de pip, que podem ser ignorados com segurança. ⚠️
#
# IGNORAR ERRO: no momento, o solucionador de dependência de pip não considera todos os pacotes instalados. Esse comportamento é a origem dos conflitos de dependência a seguir.

# %%
# %pip uninstall -y langchain langchain-core langchain-text-splitters langchain-community langchain-aws SQLAlchemy pydantic pydantic-core
# %pip install --no-build-isolation --force-reinstall \
                "boto3>=1.28.57" \
                "awscli>=1.29.57" \
                "botocore>=1.31.57"

# %pip install --quiet \
                "transformers>=4.24,<5" \
                "pypdf>=3.8" \
                datasets \
                "langchain>=0.3,<0.4" \
                "langchain-core>=0.3,<0.4" \
                "langchain-community >=0.3,<0.4" \
                "langchain-text-splitters>=0.3,<0.4" \
                "langchain-aws>=0.2,<0.3" \
                langgraph \
                "pydantic>=2,<3" \
                faiss-cpu
                
# %pip install --force-reinstall SQLAlchemy
# %pip install numexpr
# %pip install anthropic
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping langchain as it is not installed.
# WARNING: Skipping langchain-core as it is not installed.
# WARNING: Skipping langchain-text-splitters as it is not installed.
# WARNING: Skipping langchain-community as it is not installed.
# WARNING: Skipping langchain-aws as it is not installed.
# WARNING: Skipping SQLAlchemy as it is not installed.
# WARNING: Skipping pydantic as it is not installed.
# WARNING: Skipping pydantic-core as it is not installed.
# ...
#   Using cached boto3-1.42.43-py3-none-any.whl.metadata (6.8 kB)
# ...
#   Using cached awscli-1.44.33-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached botocore-1.42.43-py3-none-any.whl.metadata (5.9 kB)
# ...
#   Using cached jmespath-1.1.0-py3-none-any.whl.metadata (7.6 kB)
# ...
#   Using cached s3transfer-0.16.0-py3-none-any.whl.metadata (1.7 kB)
# ...
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# ...

# %% [markdown]
# ### Reinicie o kernel após executar a célula acima
